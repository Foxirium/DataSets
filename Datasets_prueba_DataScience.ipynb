# %% [markdown]
# <a href="https://colab.research.google.com/github/Foxirium/DataSets/blob/main/Datasets_prueba_DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/Foxirium/DataSets/main/Video_Games.csv"

# %% [markdown]
# #Primer DATASET. "Video_Games.csv"
# Tiene información sobre videojuegos, contemplando columnas de genero, empresa que lo publica, ventas por pais, puntuación de los criticos, plataforma. Sobre las mismas se podrian hacer calculos relacionados con los generos mejor puntuados por plataforma, mayor cantidad de ventas por pais y por plataforma.
# Como trabajo me gustaria predecir el genero de videojuego que seria mas viable para un proximo desarrollo de una empresa. El mismo en funcion de las ventas y las puntuaciones de los criticos / usuarios
#
#
# Este es con el que preferiría trabajar

# %%
#Leo el dataset desde la variable url que contiene el path al repositorio donde se encuentra el dataset
video_games_data = pd.read_csv(url)

#Muestro la dataset
video_games_data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
#Muestro los primeros 5 registros utilizando el metodo .head()

video_games_data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# #### Segundo DATASET. "export_import.csv"
#
# DataSet que agrupa las distintas importaciones y exportaciones de diferentes países. Las columnas como año, exportaciones (US), importaciones (US)  y las relacionadas con los Dutys (impuestos) nos pueden permitir identificar y comparar distintas politicas tarifarias entre paises y patrones de intercambio. Con la fecha establecer crecimientos y detrimentos en la cantidad de importaciones y exportaciones entre y de cada país.

# %%
url_exp_imp = "https://raw.githubusercontent.com/Foxirium/DataSets/main/export_import.csv"

# %%
#Leo el dataset desde la variable url que contiene el path al repositorio donde se encuentra el dataset
exports_imports_data = pd.read_csv(url_exp_imp)

#Muestro la dataset
exports_imports_data
# Out:
#                     Partner Name  Year  Export (US$ Thousand)  \
# 0                          Aruba  1988           3.498100e+03
# 1                    Afghanistan  1988           2.130304e+05
# 2                         Angola  1988           3.755279e+05
# 3                        Anguila  1988           3.669800e+02
# 4                        Albania  1988           3.010356e+04
# ...                          ...   ...                    ...
# 8091   Latin America & Caribbean  2021           1.330557e+09
# 8092  Middle East & North Africa  2021           1.196712e+09
# 8093               North America  2021           3.823319e+09
# 8094                  South Asia  2021           6.991380e+08
# 8095          Sub-Saharan Africa  2021           4.951000e+08
#
#       Import (US$ Thousand)  Export Product Share (%)  \
# 0              3.284900e+02                     100.0
# 1              5.445952e+04                     100.0
# 2              3.707028e+05                     100.0
# ...
